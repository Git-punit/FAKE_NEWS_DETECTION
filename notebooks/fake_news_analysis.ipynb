# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('../data/news.csv')

print(data.head())
print(data['label'].value_counts())

sns.countplot(x='label', data=data)
plt.title("Real vs Fake News Count")
plt.show()
# Out:
#                                                 text  label
# 0  The government has announced new economic reforms      1
# 1                  Scientists discover water on Mars      1
# 2             Celebrity adopts alien baby from space      0
# 3          Man claims he can time travel using phone      0
# 4          New education policy launched by ministry      1
# label
# 1    17
# 0    15
# Name: count, dtype: int64
